# %% [markdown]
# # BoneRAG - BTXRD/BTRXD GPU Embedding
#
# Notebook này mã hóa BTXRD/BTRXD thành FAISS artifacts: `btxrd_biomedclip`, `btxrd_clip_vitb32`, `btxrd_clip_vitl14`.
#
# Dataset có thể được đặt ở một trong các vị trí sau:
#
# - `/content/btxrd-data`
# - `/content/drive/MyDrive/BoneRAG_Data/btxrd-data`
# - `/content/drive/MyDrive/BoneRAG_Data/btxrd-data.zip`
#
# Hoặc dùng Kaggle API với dataset mặc định `thanhngan123/btxrd-data`.

# %%
# [Step 1] Clone / pull source code
import os

if not os.path.exists('/content/boneRAG'):
    # !git clone https://github.com/thanhnghi-do-2k3/boneRAG.git /content/boneRAG
else:
    # !cd /content/boneRAG && git pull

# %cd /content/boneRAG

# %%
# [Step 2] Optional config
# Neu ban da giai nen dataset vao Drive, khong can sua gi.
# Neu dataset nam o path khac, bo comment dong nay:
# import os
# os.environ['BONERAG_BTXRD_ROOT'] = '/content/drive/MyDrive/BoneRAG_Data/btxrd-data'

# Neu dung Kaggle API, upload kaggle.json vao /root/.kaggle/kaggle.json
# hoac set KAGGLE_USERNAME / KAGGLE_KEY. Dataset mac dinh:
# os.environ['BTXRD_KAGGLE_DATASET'] = 'thanhngan123/btxrd-data'

# %%
# [Step 3] Encode BTXRD/BTRXD
# !python3 bonerag/scripts/index_btxrd_colab.py
